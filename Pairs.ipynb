# %%
import pandas as pd
import pandas_datareader as pdr
from datetime import datetime
import yfinance as yf

def get_historical_Data(tickers):
    
    data = pd.DataFrame()
    names = list()
    for i in tickers:
        data = pd.concat([data, pd.DataFrame(yf.download(i, start=datetime(2020, 10, 27), end=datetime(2021, 10, 27)).iloc[:,4])], axis = 1)
        names.append(i)
    data.columns = names
    return data
ticks = ["DPZ", "AAPL", "GOOG", "AMD", "GME", "SPY", "NFLX", "BA", "WMT","TWTR","GS","XOM","NKE","FEYE", "FB","BRK-B", "MSFT"]
d = get_historical_Data(ticks)

print(d.shape)
d.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# (253, 17)
#                    DPZ        AAPL         GOOG        AMD    GME         SPY  \
# Date
# 2020-10-26  391.238190  114.314758  1590.449951  82.230003  13.45  334.675598
# 2020-10-27  393.637512  115.854843  1604.260010  78.879997  12.69  333.521851
# 2020-10-28  380.718872  110.489357  1516.619995  76.400002  11.82  322.122375
# 2020-10-29  383.415588  114.583023  1567.239990  78.019997  11.73  325.396301
# 2020-10-30  375.087402  108.164307  1621.010010  75.290001  10.47  322.004089
#
#                   NFLX          BA         WMT       TWTR          GS  \
# Date
# 2020-10-26  488.239990  160.830002  139.986404  49.000000  197.635818
# 2020-10-27  488.929993  155.240005  140.685547  51.270000  192.270950
# 2020-10-28  486.239990  148.139999  137.898834  48.529999  186.463928
# 2020-10-29  504.209991  148.289993  137.780670  52.430000  186.630966
# 2020-10-30  475.739990  144.389999  136.628555  41.360001  185.746628
#
#                   XOM         NKE    FEYE          FB       BRK-B        MSFT
# Date
# 2020-10-26  31.090206  127.384636  14.150  277.109985  208.490005  208.169846
# 2020-10-27  30.596123  127.007553  14.090  283.290009  206.880005  211.311005
# 2020-10-28  29.430819  121.142929  14.125  267.670013  200.699997  200.837097
# 2020-10-29  30.735956  121.916939  14.260  280.829987  201.509995  202.858566
# 2020-10-30  30.409672  119.158279  13.840  263.109985  201.899994  200.629028

# %%
#Heatmap

import seaborn as sn
from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=200)
sn.heatmap(d.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
figure(figsize=(8, 6), dpi=200)
AAPL = d['AAPL']
MSFT = d['MSFT'] 
plt.plot(SPY, label = "AAPL")
plt.plot(BRK_A, label = "MSFT")
plt.legend()

# %%
figure(figsize=(8, 6), dpi=200)
plt.plot(MSFT-AAPL, label = 'Spread AAPL _ MSFT)')
plt.legend()
plt.title("Spread between MSFT and AAPL")
# Out:
# Text(0.5, 1.0, 'Spread between MSFT and AAPL')

# %%
import statsmodels.tsa.stattools as ts 
result = ts.coint(MSFT, AAPL)
cointegration_t_statistic = result[0]
p_val = result[1]
critical_values_test_statistic_at_1_5_10 = result[2]
print('P value is', p_val)
# Out:
# P value is 0.5168507591250215

# %%
p_val=[]
